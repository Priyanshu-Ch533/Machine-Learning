# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, classification_report
import matplotlib.pyplot as plt
from sklearn import tree
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 1000
sns.set_theme(style='darkgrid', palette='rainbow')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Regression

# %%
df = pd.read_csv("C:\\Users\\Priyanshu Chauhan\\Downloads\\Boston.csv", index_col = 0)
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 1    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 3    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 4    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 5    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 1       15.3  396.90   4.98  24.0
# 2       17.8  396.90   9.14  21.6
# ...

# %%
df.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# # Model building

# %%
x = df.iloc[:,:-1]
y = df['medv']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2, random_state=1)

# %%
#Evaluating regressor

# %%
rf = RandomForestRegressor()
rf.fit(xtrain,ytrain)
ypred = rf.predict(xtest)

# %%
print(f"R2 values: {r2_score(ytest,ypred)}")
print(f"MSE: {mean_squared_error(ytest,ypred)}")
print(f"RMSE: {np.sqrt(mean_squared_error(ytest,ypred))}")
# Out:
# R2 values: 0.9102803870931123
# MSE: 8.866755127450977
# RMSE: 2.9777097117501192

# %%
#Visualize the rf

# %%
len(rf.estimators_)
# Out:
# 100

# %%
rf.estimators_[0]
# Out:
# DecisionTreeRegressor(max_features=1.0, random_state=934231434)

# %%
tree.plot_tree(rf.estimators_[0], feature_names=x.columns,
              filled=True, max_depth=2)
plt.show()

# %% [markdown]
# # Classification

# %%
#Read the dataset

# %%
df = pd.read_csv("C:\\Users\\Priyanshu Chauhan\\Downloads\\Mobile_price_range.csv")
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
sns.countplot(x = df['price_range'])
# Out:
# <Axes: xlabel='price_range', ylabel='count'>

# %%
df['price_range'].replace([0,1,2,3],['low','medium','high','very high'], inplace=True)

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#Evaluate model

# %%
x = df.iloc[:,:-1]
y = df['price_range']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2, random_state=1)

# %%
rfc = RandomForestClassifier()
rfc.fit(xtrain,ytrain)
yp = rfc.predict(xtest)

# %%
print(classification_report(ytest,yp))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.83      0.80      0.81       106
#          low       0.91      0.93      0.92        92
#       medium       0.80      0.85      0.83        96
#    very high       0.93      0.88      0.90       106
#
#     accuracy                           0.86       400
#    macro avg       0.87      0.87      0.87       400
# weighted avg       0.87      0.86      0.87       400

# %%
#Try to visualize 5 to 10 decision trees.
